# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langchain.agents import create_agent
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever

# %%
# 获取脚本所在目录
SCRIPT_DIR = Path.cwd()
DATA_DIR = SCRIPT_DIR / "data"
CHROMA_DIR = SCRIPT_DIR / "chroma_db"

# %%
DATA_DIR.mkdir(exist_ok=True)
CHROMA_DIR.mkdir(exist_ok=True)

# %%
# 加载环境变量
load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

if not GROQ_API_KEY or GROQ_API_KEY == "your_groq_api_key_here":
    raise ValueError(
        "\n请先在 .env 文件中设置有效的 GROQ_API_KEY\n"
        "访问 https://console.groq.com/keys 获取免费密钥"
    )

# %%
model = init_chat_model("groq:llama-3.3-70b-versatile", api_key=GROQ_API_KEY)

# %%
print( """
    示例1：准备测试数据

    创建包含多种信息的测试文档，用于演示不同检索方法的效果
    """)
# Out:
#     示例1：准备测试数据
#
#     创建包含多种信息的测试文档，用于演示不同检索方法的效果

# %%
print("\n" + "="*70)
print("示例 1：准备测试数据")
print("="*70)
# Out:
# ======================================================================
# 示例 1：准备测试数据
# ======================================================================

# %%
documents_text = """
# LangChain 框架详解

## 核心组件

LangChain 提供以下核心组件：

1. Models (模型接口)
   - 支持 OpenAI GPT-4, GPT-3.5
   - 支持 Anthropic Claude
   - 支持 Groq Llama 模型
   - 版本号：langchain>=1.0.0

2. Prompts (提示词模板)
   - PromptTemplate 类
   - ChatPromptTemplate 类
   - 支持变量插值

3. Chains (链式调用)
   - 已在 1.0 中废弃
   - 建议使用 LCEL (LangChain Expression Language)

4. Agents (智能代理)
   - create_agent 函数
   - 工具调用机制
   - ReAct 模式

5. Memory (记忆管理)
   - InMemorySaver 类
   - SQLite checkpointer
   - 对话历史管理

## RAG 技术栈

### 基础 RAG
- 文档加载：TextLoader, PyPDFLoader
- 文本分割：RecursiveCharacterTextSplitter
- 向量嵌入：HuggingFaceEmbeddings
- 向量存储：Pinecone, Chroma, FAISS

### 进阶 RAG
- 混合搜索：BM25 + 向量搜索
- EnsembleRetriever：组合多个检索器
- 重排序：Reranking 模型
- 查询优化：Query rewriting

## 代码示例

```python
from langchain.agents import create_agent
from langchain_core.tools import tool

@tool
def search_docs(query: str) -> str:
    \"\"\"搜索文档\"\"\"
    return "结果"

agent = create_agent(
    model=model,
    tools=[search_docs],
    system_prompt="你是助手"
)
```

## 性能优化

1. Chunk 大小：建议 500-1000 字符
2. Chunk 重叠：10-20%
3. 检索数量：k=3-5
4. 混合搜索权重：向量 0.6, BM25 0.4

## 常见问题

Q: LangChain 1.0 有什么新特性？
A: 更简洁的 API，内置 LangGraph，改进的中间件系统

Q: 如何选择向量数据库？
A: Pinecone 适合生产，Chroma 适合开发，FAISS 适合离线

Q: BM25 是什么？
A: Best Match 25，一种基于词频的检索算法，适合精确匹配
"""

# %%
# 保存文档
doc_path = DATA_DIR / "langchain_guide.txt"
with open(doc_path, "w", encoding="utf-8") as f:
    f.write(documents_text)

print(f"\n[OK] 创建测试文档: {doc_path}")
print(f"  文档长度: {len(documents_text)} 字符")
# Out:
# [OK] 创建测试文档: e:\work\05-AI-Sutdy\02-agent\03-langchain1_0\Langchain1.0-Langgraph1.0-Learning\phase2_practical\14_rag_advanced\data\langchain_guide.txt
#   文档长度: 1266 字符

# %%
# load and splitter
loader = TextLoader(doc_path,encoding="utf-8")
documents = loader.load()

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 300,
    chunk_overlap = 50,
    separators=["\n## ", "\n### ", "\n\n", "\n", " ", ""]
)

# %%
chunks = splitter.split_documents(documents)

# %%
chunks
# Out:
# [Document(metadata={'source': 'e:\\work\\05-AI-Sutdy\\02-agent\\03-langchain1_0\\Langchain1.0-Langgraph1.0-Learning\\phase2_practical\\14_rag_advanced\\data\\langchain_guide.txt'}, page_content='# LangChain 框架详解'),
#  Document(metadata={'source': 'e:\\work\\05-AI-Sutdy\\02-agent\\03-langchain1_0\\Langchain1.0-Langgraph1.0-Learning\\phase2_practical\\14_rag_advanced\\data\\langchain_guide.txt'}, page_content='## 核心组件\n\nLangChain 提供以下核心组件：\n\n1. Models (模型接口)\n   - 支持 OpenAI GPT-4, GPT-3.5\n   - 支持 Anthropic Claude\n   - 支持 Groq Llama 模型\n   - 版本号：langchain>=1.0.0\n\n2. Prompts (提示词模板)\n   - PromptTemplate 类\n   - ChatPromptTemplate 类\n   - 支持变量插值'),
#  Document(metadata={'source': 'e:\\work\\05-AI-Sutdy\\02-agent\\03-langchain1_0\\Langchain1.0-Langgraph1.0-Learning\\phase2_practical\\14_rag_advanced\\data\\langchain_guide.txt'}, page_content='3. Chains (链式调用)\n   - 已在 1.0 中废弃\n   - 建议使用 LCEL (LangChain Expression Language)\n\n4. Agents (智能代理)\n   - create_agent 函数\n   - 工具调用机制\n   - ReAct 模式\n\n5. Memory (记忆管理)\n   - InMemorySaver 类\n   - SQLite checkpointer\n   - 对话历史管理'),
#  Document(metadata={'source': 'e:\\work\\05-AI-Sutdy\\02-agent\\03-langchain1_0\\Langchain1.0-Langgraph1.0-Learning\\phase2_practical\\14_rag_advanced\\data\\langchain_guide.txt'}, page_content='## RAG 技术栈\n\n### 基础 RAG\n- 文档加载：TextLoader, PyPDFLoader\n- 文本分割：RecursiveCharacterTextSplitter\n- 向量嵌入：HuggingFaceEmbeddings\n- 向量存储：Pinecone, Chroma, FAISS\n\n### 进阶 RAG\n- 混合搜索：BM25 + 向量搜索\n- EnsembleRetriever：组合多个检索器\n- 重排序：Reranking 模型\n- 查询优化：Query rewriting'),
#  Document(metadata={'source': 'e:\\work\\05-AI-Sutdy\\02-agent\\03-langchain1_0\\Langchain1.0-Langgraph1.0-Learning\\phase2_practical\\14_rag_advanced\\data\\langchain_guide.txt'}, page_content='## 代码示例\n\n```python\nfrom langchain.agents import create_agent\nfrom langchain_core.tools import tool\n\n@tool\ndef search_docs(query: str) -> str:\n    """搜索文档"""\n    return "结果"\n\nagent = create_agent(\n    model=model,\n    tools=[search_docs],\n    system_prompt="你是助手"\n)\n```'),
#  Document(metadata={'source': 'e:\\work\\05-AI-Sutdy\\02-agent\\03-langchain1_0\\Langchain1.0-Langgraph1.0-Learning\\phase2_practical\\14_rag_advanced\\data\\langchain_guide.txt'}, page_content='## 性能优化\n\n1. Chunk 大小：建议 500-1000 字符\n2. Chunk 重叠：10-20%\n3. 检索数量：k=3-5\n4. 混合搜索权重：向量 0.6, BM25 0.4\n\n## 常见问题\n\nQ: LangChain 1.0 有什么新特性？\nA: 更简洁的 API，内置 LangGraph，改进的中间件系统\n\nQ: 如何选择向量数据库？\nA: Pinecone 适合生产，Chroma 适合开发，FAISS 适合离线\n\nQ: BM25 是什么？\nA: Best Match 25，一种基于词频的检索算法，适合精确匹配')]

# %%
print(f"\n分割结果:")
print(f"  原文档: {len(documents)} 个")
print(f"  分割后: {len(chunks)} 块")
print(f"\n前 3 块示例:")
for i, chunk in enumerate(chunks[:3], 1):
    preview = chunk.page_content[:60].replace("\n", " ")
    print(f"  块 {i}: {preview}...")
# Out:
# 分割结果:
#   原文档: 1 个
#   分割后: 6 块
#
# 前 3 块示例:
#   块 1: # LangChain 框架详解...
#   块 2: ## 核心组件  LangChain 提供以下核心组件：  1. Models (模型接口)    - 支持 OpenA...
#   块 3: 3. Chains (链式调用)    - 已在 1.0 中废弃    - 建议使用 LCEL (LangChain E...

# %%
print("""
示例2：向量检索器

使用向量嵌入进行语义搜索
""")
print("\n" + "="*70)
print("示例 2：向量检索器 (语义搜索)")
print("="*70)
# Out:
# 示例2：向量检索器
#
# 使用向量嵌入进行语义搜索
#
#
# ======================================================================
# 示例 2：向量检索器 (语义搜索)
# ======================================================================

# %%
print("\n创建向量存储...")
print("  使用: HuggingFaceEmbeddings (all-MiniLM-L6-v2)")
print("  存储: Chroma (本地)")
# Out:
# 创建向量存储...
#   使用: HuggingFaceEmbeddings (all-MiniLM-L6-v2)
#   存储: Chroma (本地)

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_openai import OpenAIEmbeddings
# 创建嵌入模型
embeddings = OpenAIEmbeddings(
    model=os.getenv("LOCAL_EMBEDDING_MODEL"),
    base_url=os.getenv("LOCAL_BASE_URL"),
    api_key=os.getenv("LOCAL_API_KEY"),
    dimensions=1024,
)

# %%
# 创建 Chroma 向量存储

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding = embeddings,
    persist_directory = str(CHROMA_DIR)
)

# %%
# 创建检索器
vector_retriever = vectorstore.as_retriever(
    search_kwars={"k":3}
)

# %%
print(f"\n[OK] 向量检索器已创建")
print(f"  检索数量: k=3")
# Out:
# [OK] 向量检索器已创建
#   检索数量: k=3

# %%
# 测试查询
test_queries = [
    "LangChain 有哪些核心组件？",  # 语义查询
    "如何优化 RAG 性能？",          # 概念查询
    "BM25 算法",                    # 精确术语
]

# %%
print(f"\n测试查询:")
for i, query in enumerate(test_queries, 1):
    print(f"\n  查询 {i}: {query}")
    results = vector_retriever.invoke(query)
    print(f"  结果数: {len(results)}")
    if results:
        preview = results[0].page_content[:80].replace("\n", " ")
        print(f"  最相关: {preview}...")
# Out:
# 测试查询:
#
#   查询 1: LangChain 有哪些核心组件？
#   结果数: 4
#   最相关: ## 核心组件  LangChain 提供以下核心组件：  1. Models (模型接口)    - 支持 OpenAI GPT-4, GPT-3.5    ...
#
#   查询 2: 如何优化 RAG 性能？
#   结果数: 4
#   最相关: ## RAG 技术栈  ### 基础 RAG - 文档加载：TextLoader, PyPDFLoader - 文本分割：RecursiveCharacterT...
#
#   查询 3: BM25 算法
#   结果数: 4
#   最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索数量：k=3-5 4. 混合搜索权重：向...

# %%
print( """
    示例3：BM25 检索器

    使用 BM25 算法进行关键词匹配
    """)
# Out:
#     示例3：BM25 检索器
#
#     使用 BM25 算法进行关键词匹配

# %%
print("\n" + "="*70)
print("示例 3：BM25 检索器 (关键词搜索)")
print("="*70)
# Out:
# ======================================================================
# 示例 3：BM25 检索器 (关键词搜索)
# ======================================================================

# %%
print("\n什么是 BM25？")
print("  全称: Best Match 25")
print("  类型: 基于词频的检索算法")
print("  优势: 精确匹配专有名词、代码、版本号")
print("  原理: TF-IDF 的改进版本")
# Out:
# 什么是 BM25？
#   全称: Best Match 25
#   类型: 基于词频的检索算法
#   优势: 精确匹配专有名词、代码、版本号
#   原理: TF-IDF 的改进版本

# %%
bm25_retriever = BM25Retriever.from_documents(chunks)
bm25_retriever.k = 3

# %%
print(f"\n[OK] BM25 检索器已创建")
print(f"  检索数量: k=3")
# Out:
# [OK] BM25 检索器已创建
#   检索数量: k=3

# %%
# 测试查询
test_queries = [
    "LangChain 有哪些核心组件？",  # 语义查询
    "如何优化 RAG 性能？",          # 概念查询
    "BM25 算法",                    # 精确术语
]

# %%
print(f"\n测试查询:")
for i, query in enumerate(test_queries, 1):
    print(f"\n  查询 {i}: {query}")
    results = bm25_retriever.invoke(query)
    print(f"  结果数: {len(results)}")
    if results:
        preview = results[0].page_content[:80].replace("\n", " ")
        print(f"  最相关: {preview}...")
# Out:
# 测试查询:
#
#   查询 1: LangChain 有哪些核心组件？
#   结果数: 3
#   最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索数量：k=3-5 4. 混合搜索权重：向...
#
#   查询 2: 如何优化 RAG 性能？
#   结果数: 3
#   最相关: ## RAG 技术栈  ### 基础 RAG - 文档加载：TextLoader, PyPDFLoader - 文本分割：RecursiveCharacterT...
#
#   查询 3: BM25 算法
#   结果数: 3
#   最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索数量：k=3-5 4. 混合搜索权重：向...

# %%
print( """
    示例4：混合检索器

    组合向量搜索和 BM25，使用 RRF (Reciprocal Rank Fusion) 算法
    """)
# Out:
#     示例4：混合检索器
#
#     组合向量搜索和 BM25，使用 RRF (Reciprocal Rank Fusion) 算法

# %%
print("\n" + "="*70)
print("示例 4：混合检索器 (Ensemble Retriever)")
print("="*70)
# Out:
# ======================================================================
# 示例 4：混合检索器 (Ensemble Retriever)
# ======================================================================

# %%
print("\n混合检索原理:")
print("  1. 向量搜索: 擅长语义理解、同义词、概念")
print("  2. BM25 搜索: 擅长精确匹配、专有名词、代码")
print("  3. RRF 算法: 融合两者的排名结果")
# Out:
# 混合检索原理:
#   1. 向量搜索: 擅长语义理解、同义词、概念
#   2. BM25 搜索: 擅长精确匹配、专有名词、代码
#   3. RRF 算法: 融合两者的排名结果

# %%
print("\n权重说明:")
print("  weights=[0.5, 0.5] - 平衡")
print("  weights=[0.7, 0.3] - 偏向向量")
print("  weights=[0.3, 0.7] - 偏向 BM25")
# Out:
# 权重说明:
#   weights=[0.5, 0.5] - 平衡
#   weights=[0.7, 0.3] - 偏向向量
#   weights=[0.3, 0.7] - 偏向 BM25

# %%
ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retriever,vector_retriever],
    weights=[0.4,0.6]
)

# %%
print(f"\n[OK] 混合检索器已创建")
print(f"  组合: BM25 (40%) + Vector (60%)")
print(f"  算法: RRF (Reciprocal Rank Fusion)")
# Out:
# [OK] 混合检索器已创建
#   组合: BM25 (40%) + Vector (60%)
#   算法: RRF (Reciprocal Rank Fusion)

# %%
# 对比测试
test_queries = [
    ("语义查询", "LangChain 的主要功能是什么？"),
    ("精确匹配", "langchain>=1.0.0"),
    ("混合查询", "BM25 算法如何工作？"),
]

# %%
print(f"\n对比测试:")
for query_type, query in test_queries:
    print(f"\n  [{query_type}] {query}")

    # BM25 结果
    bm25_results = bm25_retriever.invoke(query)
    bm25_preview = bm25_results[0].page_content[:50].replace("\n", " ") if bm25_results else "无"

    # 向量结果
    vector_results = vector_retriever.invoke(query)
    vector_preview = vector_results[0].page_content[:50].replace("\n", " ") if vector_results else "无"

    # 混合结果
    ensemble_results = ensemble_retriever.invoke(query)
    ensemble_preview = ensemble_results[0].page_content[:50].replace("\n", " ") if ensemble_results else "无"

    print(f"    BM25:    {bm25_preview}...")
    print(f"    Vector:  {vector_preview}...")
    print(f"    Hybrid:  {ensemble_preview}...")
# Out:
# 对比测试:
#
#   [语义查询] LangChain 的主要功能是什么？
#     BM25:    ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10...
#     Vector:  # LangChain 框架详解...
#     Hybrid:  # LangChain 框架详解...
#
#   [精确匹配] langchain>=1.0.0
#     BM25:    ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10...
#     Vector:  # LangChain 框架详解...
#     Hybrid:  ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10...
#
#   [混合查询] BM25 算法如何工作？
#     BM25:    ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10...
#     Vector:  ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10...
#     Hybrid:  ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10...

# %%
print("\n关键点:")
print("  - 混合检索结合了两者的优势")
print("  - 对大多数查询都能获得更好的结果")
print("  - 适用于生产环境")
# Out:
# 关键点:
#   - 混合检索结合了两者的优势
#   - 对大多数查询都能获得更好的结果
#   - 适用于生产环境

# %%
"""
示例5：权重优化

测试不同权重配置的效果
"""
print("\n" + "="*70)
print("示例 5：权重优化实验")
print("="*70)

print("\n测试不同的权重配置...")
# Out:
# ======================================================================
# 示例 5：权重优化实验
# ======================================================================
#
# 测试不同的权重配置...

# %%
weight_configs = [
    (0.0, 1.0, "纯向量"),
    (0.3, 0.7, "偏向向量"),
    (0.5, 0.5, "平衡"),
    (0.7, 0.3, "偏向 BM25"),
    (1.0, 0.0, "纯 BM25"),
]

# %%
test_query = "LangChain 1.0 有什么新特性？"

print(f"\n测试查询: {test_query}")
print("\n权重配置对比:")
# Out:
# 测试查询: LangChain 1.0 有什么新特性？
#
# 权重配置对比:

# %%
for bm25_weight, vector_weight, description in weight_configs:
    ensemble = EnsembleRetriever(
        retrievers=[bm25_retriever, vector_retriever],
        weights=[bm25_weight, vector_weight]
    )

    results = ensemble.invoke(test_query)
    if results:
        preview = results[0].page_content[:60].replace("\n", " ")
        print(f"\n  {description} [{bm25_weight:.1f}, {vector_weight:.1f}]:")
        print(f"    最相关: {preview}...")
# Out:
#   纯向量 [0.0, 1.0]:
#     最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索...
#
#   偏向向量 [0.3, 0.7]:
#     最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索...
#
#   平衡 [0.5, 0.5]:
#     最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索...
#
#   偏向 BM25 [0.7, 0.3]:
#     最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索...
#
#   纯 BM25 [1.0, 0.0]:
#     最相关: ## 性能优化  1. Chunk 大小：建议 500-1000 字符 2. Chunk 重叠：10-20% 3. 检索...

# %%
print("\n推荐配置:")
print("  - 技术文档: [0.4, 0.6] - 稍偏向语义")
print("  - 代码搜索: [0.6, 0.4] - 稍偏向精确匹配")
print("  - 通用场景: [0.5, 0.5] - 平衡")
# Out:
# 推荐配置:
#   - 技术文档: [0.4, 0.6] - 稍偏向语义
#   - 代码搜索: [0.6, 0.4] - 稍偏向精确匹配
#   - 通用场景: [0.5, 0.5] - 平衡

# %%
print( """
    示例6：使用混合检索的 RAG Agent

    将混合检索集成到 Agent 中
    """)
# Out:
#     示例6：使用混合检索的 RAG Agent
#
#     将混合检索集成到 Agent 中

# %%
print("\n" + "="*70)
print("示例 6：RAG Agent with Hybrid Search")
print("="*70)

print("\n创建混合检索工具...")
# Out:
# ======================================================================
# 示例 6：RAG Agent with Hybrid Search
# ======================================================================
#
# 创建混合检索工具...

# %%
# 创建检索工具
@tool
def search_knowledge_base(query: str) -> str:
    """在知识库中搜索相关信息（混合检索）"""
    docs = ensemble_retriever.invoke(query)
    return "\n\n".join([doc.page_content for doc in docs[:2]])  # 只取前2个

print(f"[OK] 工具已创建: search_knowledge_base")
# Out:
# [OK] 工具已创建: search_knowledge_base

# %%
# 创建 Agent
agent = create_agent(
    model=model,
    tools=[search_knowledge_base],
    system_prompt="""你是一个 LangChain 专家助手。

使用 search_knowledge_base 工具搜索相关信息，然后回答问题。

注意：
1. 优先使用检索到的信息
2. 如果信息不足，诚实告知
3. 回答要简洁准确"""
)

print(f"[OK] Agent 已创建\n")
# Out:
# [OK] Agent 已创建

# %%
# 测试问答
questions = [
    "LangChain 有哪些核心组件？",
    "如何优化 RAG 性能？",
]

for question in questions:
    print(f"问题: {question}")
    try:
        response = agent.invoke({
            "messages": [{"role": "user", "content": question}]
        })
        print(f"回答: {response['messages'][-1].content}\n")
        print(response)
    except Exception as e:
        print(f"[错误] 查询失败（Groq 工具调用问题）\n")
    print("-" * 70 + "\n")
# Out:
# 问题: LangChain 有哪些核心组件？
# 回答: LangChain 的核心组件包括 Models（模型接口）、Prompts（提示词模板）等。Models 支持多种语言模型，如 OpenAI GPT-4、GPT-3.5、Anthropic Claude 和 Groq Llama 模型。Prompts 提供了 PromptTemplate 和 ChatPromptTemplate 类，支持变量插值。这些组件为构建和定制语言模型应用提供了基础。
#
# {'messages': [HumanMessage(content='LangChain 有哪些核心组件？', additional_kwargs={}, response_metadata={}, id='d338ede7-e3f0-4e56-8fe9-3b47d6bf09a2'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'qx3te2eas', 'function': {'arguments': '{"query":"LangChain \\\\u5199\\\\u6ce8\\\\u4e3b\\\\u9898\\\\u6218\\\\u5458\\\\u6838\\\\u5fc3\\\\u7ec4\\\\u4ef6"}', 'name': 'search_knowledge_base'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 293, 'total_tokens': 356, 'completion_time': 0.262576331, 'completion_tokens_details': None, 'prompt_time': 0.027597328, 'prompt_tokens_details': None, 'queue_time': 0.080168835, 'total_time': 0.290173659}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_93b5f9e564', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b4515-3dba-7040-abcf-40588c7ca36c-0', tool_calls=[{'name': 'search_knowledge_base', 'args': {'query': 'LangChain \\u5199\\u6ce8\\u4e3b\\u9898\\u6218\\u5458\\u6838\\u5fc3\\u7ec4\\u4ef6'}, 'id': 'qx3te2eas', 'type': 'tool_call'}], usage_metadata={'input_tokens': 293, 'output_tokens': 63, 'total_tokens': 356}), ToolMessage(content='## 性能优化\n\n1. Chunk 大小：建议 500-1000 字符\n2. Chunk 重叠：10-20%\n3. 检索数量：k=3-5\n4. 混合搜索权重：向量 0.6, BM25 0.4\n\n## 常见问题\n\nQ: LangChain 1.0 有什么新特性？\nA: 更简洁的 API，内置 LangGraph，改进的中间件系统\n\nQ: 如何选择向量数据库？\nA: Pinecone 适合生产，Chroma 适合开发，FAISS 适合离线\n\nQ: BM25 是什么？\nA: Best Match 25，一种基于词频的检索算法，适合精确匹配\n\n## 核心组件\n\nLangChain 提供以下核心组件：\n\n1. Models (模型接口)\n   - 支持 OpenAI GPT-4, GPT-3.5\n   - 支持 Anthropic Claude\n   - 支持 Groq Llama 模型\n   - 版本号：langchain>=1.0.0\n\n2. Prompts (提示词模板)\n   - PromptTemplate 类\n   - ChatPromptTemplate 类\n   - 支持变量插值', name='search_knowledge_base', id='2b8bfe42-15d7-4b7e-a160-29cb228c774d', tool_call_id='qx3te2eas'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'zzyamw0jn', 'function': {'arguments': '{"query":"LangChain \\\\u6838\\\\u5fc3\\\\u7ec4\\\\u4ef6"}', 'name': 'search_knowledge_base'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 646, 'total_tokens': 682, 'completion_time': 0.053233481, 'completion_tokens_details': None, 'prompt_time': 0.032788987, 'prompt_tokens_details': None, 'queue_time': 0.069388552, 'total_time': 0.086022468}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_43d97c5965', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b4515-43b7-7291-a1db-eba1e84cf730-0', tool_calls=[{'name': 'search_knowledge_base', 'args': {'query': 'LangChain \\u6838\\u5fc3\\u7ec4\\u4ef6'}, 'id': 'zzyamw0jn', 'type': 'tool_call'}], usage_metadata={'input_tokens': 646, 'output_tokens': 36, 'total_tokens': 682}), ToolMessage(content='# LangChain 框架详解\n\n## 核心组件\n\nLangChain 提供以下核心组件：\n\n1. Models (模型接口)\n   - 支持 OpenAI GPT-4, GPT-3.5\n   - 支持 Anthropic Claude\n   - 支持 Groq Llama 模型\n   - 版本号：langchain>=1.0.0\n\n2. Prompts (提示词模板)\n   - PromptTemplate 类\n   - ChatPromptTemplate 类\n   - 支持变量插值', name='search_knowledge_base', id='fbf03429-23db-42c8-a9ba-3f4826f87874', tool_call_id='zzyamw0jn'), AIMessage(content='LangChain 的核心组件包括 Models（模型接口）、Prompts（提示词模板）等。Models 支持多种语言模型，如 OpenAI GPT-4、GPT-3.5、Anthropic Claude 和 Groq Llama 模型。Prompts 提供了 PromptTemplate 和 ChatPromptTemplate 类，支持变量插值。这些组件为构建和定制语言模型应用提供了基础。', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 809, 'total_tokens': 902, 'completion_time': 0.275737183, 'completion_tokens_details': None, 'prompt_time': 0.079077934, 'prompt_tokens_details': None, 'queue_time': 0.080596729, 'total_time': 0.354815117}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_bebe2dd4fb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019b4515-457d-7b22-80bb-c0f9a64a51a6-0', usage_metadata ...
# ----------------------------------------------------------------------
#
# 问题: 如何优化 RAG 性能？
# [错误] 查询失败（Groq 工具调用问题）
#
# ----------------------------------------------------------------------

# %%
print("关键点:")
print("  - 混合检索提供更全面的上下文")
print("  - 同时覆盖语义和精确匹配")
print("  - 提高 RAG 系统的准确性和鲁棒性")
# Out:
# 关键点:
#   - 混合检索提供更全面的上下文
#   - 同时覆盖语义和精确匹配
#   - 提高 RAG 系统的准确性和鲁棒性
